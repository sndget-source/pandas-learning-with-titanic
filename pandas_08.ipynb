# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Age'].median()
# Out:
# np.float64(28.0)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['Age'].count()
# Out:
# np.int64(714)

# %%
df['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 30.00    25
#          ..
# 24.50     1
# 0.67      1
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
df['Age'].value_counts(normalize= True)
# Out:
# Age
# 24.00    0.042017
# 22.00    0.037815
# 18.00    0.036415
# 28.00    0.035014
# 30.00    0.035014
#            ...
# 24.50    0.001401
# 0.67     0.001401
# 0.42     0.001401
# 34.50    0.001401
# 74.00    0.001401
# Name: proportion, Length: 88, dtype: float64

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df.groupby(['Age'])

# %%
age_grp = df.groupby(['Age'])

# %%
age_grp.get_group(24.00,)
# Out:
# C:\Users\Shalini Balla\AppData\Local\Temp\ipykernel_11932\599110485.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   age_grp.get_group(24.00,)
#      PassengerId  Survived  Pclass  \
# 89            90         0       3
# 118          119         0       1
# 127          128         1       3
# 139          140         0       1
# 142          143         1       3
# 199          200         0       2
# 210          211         0       3
# 234          235         0       2
# 247          248         1       2
# 293          294         0       3
# 294          295         0       3
# 310          311         1       1
# 316          317         1       2
# 341          342         1       1
# 345          346         1       2
# 369          370         1       1
# 394          395         1       3
# ...

# %%
age_grp.get_group(10.00,)
# Out:
# C:\Users\Shalini Balla\AppData\Local\Temp\ipykernel_11932\3760328657.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   age_grp.get_group(10.00,)
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 419          420         0       3     Van Impe, Miss. Catharina  female
# 819          820         0       3  Skoog, Master. Karl Thorsten    male
#
#       Age  SibSp  Parch  Ticket   Fare Cabin Embarked
# 419  10.0      0      2  345773  24.15   NaN        S
# 819  10.0      3      2  347088  27.90   NaN        S

# %%
age_grp['Sex'].value_counts().head(50)
# Out:
# Age    Sex
# 0.42   male       1
# 0.67   male       1
# 0.75   female     2
# 0.83   male       2
# 0.92   male       1
# 1.00   male       5
#        female     2
# 2.00   female     6
#        male       4
# 3.00   male       4
#        female     2
# 4.00   female     5
#        male       5
# 5.00   female     4
# 6.00   female     2
#        male       1
# 7.00   male       2
#        female     1
# 8.00   female     2
#        male       2
# 9.00   female     4
#        male       4
# 10.00  female     1
#        male       1
# 11.00  male       3
#        female     1
# 12.00  male       1
# 13.00  female     2
# 14.00  female     4
#        male       2
# 14.50  female     1
# 15.00  female     4
#        male       1
# 16.00  male      11
#        female     6
# 17.00  male       7
#        female     6
# 18.00  female    13
#        male      13
# 19.00  male      18
#        female     7
# 20.00  male      13
#        female     2
# 20.50  male       1
# ...

# %%
age_grp['Sex'].value_counts().loc[23.00]
# Out:
# Sex
# male      10
# female     5
# Name: count, dtype: int64

# %%
age_grp['Survived'].median().head(50)
# Out:
# Age
# 0.42     1.0
# 0.67     1.0
# 0.75     1.0
# 0.83     1.0
# 0.92     1.0
# 1.00     1.0
# 2.00     0.0
# 3.00     1.0
# 4.00     1.0
# 5.00     1.0
# 6.00     1.0
# 7.00     0.0
# 8.00     0.5
# 9.00     0.0
# 10.00    0.0
# 11.00    0.0
# 12.00    1.0
# 13.00    1.0
# 14.00    0.5
# 14.50    0.0
# 15.00    1.0
# 16.00    0.0
# 17.00    0.0
# 18.00    0.0
# 19.00    0.0
# 20.00    0.0
# 20.50    0.0
# 21.00    0.0
# 22.00    0.0
# 23.00    0.0
# 23.50    0.0
# 24.00    0.5
# 24.50    0.0
# 25.00    0.0
# 26.00    0.0
# 27.00    1.0
# 28.00    0.0
# 28.50    0.0
# 29.00    0.0
# 30.00    0.0
# 30.50    0.0
# 31.00    0.0
# 32.00    0.5
# 32.50    0.5
# 33.00    0.0
# 34.00    0.0
# 34.50    0.0
# 35.00    1.0
# 36.00    0.5
# 36.50    0.0
# Name: Survived, dtype: float64

# %%
age_grp['Survived'].agg(['median','mean'])
# Out:
#        median  mean
# Age
# 0.42      1.0   1.0
# 0.67      1.0   1.0
# 0.75      1.0   1.0
# 0.83      1.0   1.0
# 0.92      1.0   1.0
# ...       ...   ...
# 70.00     0.0   0.0
# 70.50     0.0   0.0
# 71.00     0.0   0.0
# 74.00     0.0   0.0
# 80.00     1.0   1.0
#
# [88 rows x 2 columns]

# %%
age_grp['Survived'].agg(['median','mean']).loc[50.00]
# Out:
# median    0.5
# mean      0.5
# Name: 50.0, dtype: float64

# %%
df['Survived'].value_counts(normalize = True)
# Out:
# Survived
# 0    0.616162
# 1    0.383838
# Name: proportion, dtype: float64
