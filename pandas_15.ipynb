# %%
import pandas as pd

# %%
df = pd.read_csv('smart_mobility_dataset.csv')

# %%
df.head()
# Out:
#              Timestamp   Latitude  Longitude  Vehicle_Count  \
# 0  2024-03-01 00:00:00  40.842275 -73.703149            205
# 1  2024-03-01 00:05:00  40.831119 -73.987354            202
# 2  2024-03-01 00:10:00  40.819549 -73.732462            252
# 3  2024-03-01 00:15:00  40.725849 -73.980134             37
# 4  2024-03-01 00:20:00  40.813265 -73.961631             64
#
#    Traffic_Speed_kmh  Road_Occupancy_% Traffic_Light_State Weather_Condition  \
# 0          49.893435         82.652780              Yellow             Clear
# 1          22.383965         45.829298               Green             Clear
# 2          46.889699         82.772465               Green              Rain
# 3           5.730536         37.695567                 Red               Fog
# 4          61.348034         22.313358                 Red              Snow
#
#    Accident_Report  Sentiment_Score  Ride_Sharing_Demand  \
# 0                0        -0.609199                    2
# ...

# %%
df.shape
# Out:
# (5000, 15)

# %%
df.dtypes
# Out:
# Timestamp                  object
# Latitude                  float64
# Longitude                 float64
# Vehicle_Count               int64
# Traffic_Speed_kmh         float64
# Road_Occupancy_%          float64
# Traffic_Light_State        object
# Weather_Condition          object
# Accident_Report             int64
# Sentiment_Score           float64
# Ride_Sharing_Demand         int64
# Parking_Availability        int64
# Emission_Levels_g_km      float64
# Energy_Consumption_L_h    float64
# Traffic_Condition          object
# dtype: object

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# %%
df.dtypes
# Out:
# Timestamp                 datetime64[ns]
# Latitude                         float64
# Longitude                        float64
# Vehicle_Count                      int64
# Traffic_Speed_kmh                float64
# Road_Occupancy_%                 float64
# Traffic_Light_State               object
# Weather_Condition                 object
# Accident_Report                    int64
# Sentiment_Score                  float64
# Ride_Sharing_Demand                int64
# Parking_Availability               int64
# Emission_Levels_g_km             float64
# Energy_Consumption_L_h           float64
# Traffic_Condition                 object
# dtype: object

# %%
df['Timestamp'].head()
# Out:
# 0   2024-03-01 00:00:00
# 1   2024-03-01 00:05:00
# 2   2024-03-01 00:10:00
# 3   2024-03-01 00:15:00
# 4   2024-03-01 00:20:00
# Name: Timestamp, dtype: datetime64[ns]

# %%
df.loc[0,'Timestamp'].day_name()
# Out:
# 'Friday'

# %%
df['Timestamp'].dt.day_name()
# Out:
# 0       Friday
# 1       Friday
# 2       Friday
# 3       Friday
# 4       Friday
#          ...
# 4995    Monday
# 4996    Monday
# 4997    Monday
# 4998    Monday
# 4999    Monday
# Name: Timestamp, Length: 5000, dtype: object

# %%
df['WeekDay'] = df['Timestamp'].dt.day_name()

# %%
df['WeekDay'].head()
# Out:
# 0    Friday
# 1    Friday
# 2    Friday
# 3    Friday
# 4    Friday
# Name: WeekDay, dtype: object

# %%
df['Timestamp'].min()
# Out:
# Timestamp('2024-03-01 00:00:00')

# %%
df['Timestamp'].max()
# Out:
# Timestamp('2024-03-18 08:35:00')

# %%
df['Timestamp'].max() - df['Timestamp'].min()
# Out:
# Timedelta('17 days 08:35:00')

# %%
filt = (df['Timestamp']>=pd.to_datetime('2024-03-06')) & (df['Timestamp']<pd.to_datetime('2024-03-08'))

# %%
df.loc[filt]
# Out:
#                Timestamp   Latitude  Longitude  Vehicle_Count  \
# 1440 2024-03-06 00:00:00  40.678045 -73.833114            150
# 1441 2024-03-06 00:05:00  40.788176 -73.850619             87
# 1442 2024-03-06 00:10:00  40.661244 -73.917776             60
# 1443 2024-03-06 00:15:00  40.825360 -73.955367             77
# 1444 2024-03-06 00:20:00  40.739373 -73.996003             95
# ...                  ...        ...        ...            ...
# 2011 2024-03-07 23:35:00  40.865410 -73.952534             64
# 2012 2024-03-07 23:40:00  40.740406 -73.896931             19
# 2013 2024-03-07 23:45:00  40.681694 -73.821291            270
# 2014 2024-03-07 23:50:00  40.712010 -73.924560            164
# 2015 2024-03-07 23:55:00  40.891968 -73.921370             84
#
#       Traffic_Speed_kmh  Road_Occupancy_% Traffic_Light_State  \
# 1440          24.749331         86.114514              Yellow
# 1441          10.366083         31.627143                 Red
# ...

# %%
df.set_index('Timestamp',inplace = True)

# %%
df.head()
# Out:
#                       Latitude  Longitude  Vehicle_Count  Traffic_Speed_kmh  \
# Timestamp
# 2024-03-01 00:00:00  40.842275 -73.703149            205          49.893435
# 2024-03-01 00:05:00  40.831119 -73.987354            202          22.383965
# 2024-03-01 00:10:00  40.819549 -73.732462            252          46.889699
# 2024-03-01 00:15:00  40.725849 -73.980134             37           5.730536
# 2024-03-01 00:20:00  40.813265 -73.961631             64          61.348034
#
#                      Road_Occupancy_% Traffic_Light_State Weather_Condition  \
# Timestamp
# 2024-03-01 00:00:00         82.652780              Yellow             Clear
# 2024-03-01 00:05:00         45.829298               Green             Clear
# 2024-03-01 00:10:00         82.772465               Green              Rain
# 2024-03-01 00:15:00         37.695567                 Red               Fog
# 2024-03-01 00:20:00         22.313358                 Red              Snow
#
# ...

# %%
df['2024-03-02':'2024-03-03']
# Out:
#                       Latitude  Longitude  Vehicle_Count  Traffic_Speed_kmh  \
# Timestamp
# 2024-03-02 00:00:00  40.826358 -73.900346            168          25.103960
# 2024-03-02 00:05:00  40.717416 -73.738426            278          48.897170
# 2024-03-02 00:10:00  40.860844 -73.905951             90          53.307173
# 2024-03-02 00:15:00  40.655837 -73.863155            233          52.467870
# 2024-03-02 00:20:00  40.601278 -73.813380            117          58.110482
# ...                        ...        ...            ...                ...
# 2024-03-03 23:35:00  40.839460 -73.930618            194          19.259475
# 2024-03-03 23:40:00  40.805824 -73.918952             58          70.794786
# 2024-03-03 23:45:00  40.764906 -73.995060             70          38.804872
# 2024-03-03 23:50:00  40.654423 -73.707114             92          35.583311
# 2024-03-03 23:55:00  40.793408 -73.995782            133          29.206761
#
# ...

# %%
df['2024-03-02':'2024-03-03']['Accident_Report']
# Out:
# Timestamp
# 2024-03-02 00:00:00    0
# 2024-03-02 00:05:00    0
# 2024-03-02 00:10:00    0
# 2024-03-02 00:15:00    0
# 2024-03-02 00:20:00    0
#                       ..
# 2024-03-03 23:35:00    0
# 2024-03-03 23:40:00    0
# 2024-03-03 23:45:00    0
# 2024-03-03 23:50:00    0
# 2024-03-03 23:55:00    0
# Name: Accident_Report, Length: 576, dtype: int64

# %%
df['2024-03-02':'2024-03-03']['Accident_Report'].mean()
# Out:
# np.float64(0.08854166666666667)

# %%
df['2024-03-01':'2024-03-15']['Accident_Report'].max()
# Out:
# np.int64(1)

# %%
df['2024-03-01':'2024-03-15']['Road_Occupancy_%'].mean()
# Out:
# np.float64(54.87620710234732)

# %%
df['Road_Occupancy_%'].resample('D').mean()
# Out:
# Timestamp
# 2024-03-01    55.744467
# 2024-03-02    53.984485
# 2024-03-03    54.867918
# 2024-03-04    54.657900
# 2024-03-05    52.599756
# 2024-03-06    55.661133
# 2024-03-07    58.663826
# 2024-03-08    52.947010
# 2024-03-09    53.280361
# 2024-03-10    53.869411
# 2024-03-11    57.038327
# 2024-03-12    55.415035
# 2024-03-13    52.867736
# 2024-03-14    57.174567
# 2024-03-15    54.371175
# 2024-03-16    52.548660
# 2024-03-17    54.929886
# 2024-03-18    55.028354
# Freq: D, Name: Road_Occupancy_%, dtype: float64

# %%
high = df['Road_Occupancy_%'].resample('D').max()

# %%
high['2024-03-15']
# Out:
# np.float64(99.65648574386408)

# %%
# %matplotlib inline

# %%
high.plot()
# Out:
# <Axes: xlabel='Timestamp'>

# %%
df['Vehicle_Count'].resample('W').mean()
# Out:
# Timestamp
# 2024-03-03    153.873843
# 2024-03-10    153.066964
# 2024-03-17    155.228175
# 2024-03-24    145.538462
# Freq: W-SUN, Name: Vehicle_Count, dtype: float64

# %%
df.resample('W').agg({'Traffic_Speed_kmh':'max','Sentiment_Score':'mean','Ride_Sharing_Demand':'min','Parking_Availability':'max','Emission_Levels_g_km':'median','Energy_Consumption_L_h':'mean'})
# Out:
#             Traffic_Speed_kmh  Sentiment_Score  Ride_Sharing_Demand  \
# Timestamp
# 2024-03-03          79.997556        -0.001389                    1
# 2024-03-10          79.968768        -0.014366                    1
# 2024-03-17          79.979901        -0.002207                    1
# 2024-03-24          78.303352         0.061067                    1
#
#             Parking_Availability  Emission_Levels_g_km  Energy_Consumption_L_h
# Timestamp
# 2024-03-03                    49            277.348481               16.938426
# 2024-03-10                    49            267.398312               17.554735
# 2024-03-17                    49            274.158006               17.278798
# 2024-03-24                    49            234.764588               17.855905
