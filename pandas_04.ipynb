# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Survived']==1
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889     True
# 890    False
# Name: Survived, Length: 891, dtype: bool

# %%
filt = (df['Survived']==1)

# %%
df[filt]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Survived']==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.loc[filt]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.loc[filt,'Name']
# Out:
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 8      Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                    Nasser, Mrs. Nicholas (Adele Achem)
#                              ...
# 875                     Najib, Miss. Adele Kiamie "Jane"
# 879        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 880         Shelley, Mrs. William (Imanita Parrish Hall)
# 887                         Graham, Miss. Margaret Edith
# 889                                Behr, Mr. Karl Howell
# Name: Name, Length: 342, dtype: object

# %%
filt = (df['Survived'] == 1 ) & (df['Age'] == 19.0)

# %%
df.loc[filt,['Name','Age','Survived']]
# Out:
#                                                   Name   Age  Survived
# 44                       Devaney, Miss. Margaret Delia  19.0         1
# 136                       Newsom, Miss. Helen Monypeny  19.0         1
# 192    Andersen-Jensen, Miss. Carla Christine Nielsine  19.0         1
# 226                          Mellors, Mr. William John  19.0         1
# 283                         Dorking, Mr. Edward Arthur  19.0         1
# 291            Bishop, Mrs. Dickinson H (Helen Walton)  19.0         1
# 427  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  19.0         1
# 546                  Beane, Mrs. Edward (Ethel Clarke)  19.0         1
# 887                       Graham, Miss. Margaret Edith  19.0         1

# %%
filt = (df['Age'] >= 20.0 ) & (df['Age'] <= 25.0)

# %%
df.loc[filt,['Name','Age']]
# Out:
#                                              Name   Age
# 0                         Braund, Mr. Owen Harris  22.0
# 12                 Saundercock, Mr. William Henry  20.0
# 37                       Cann, Mr. Ernest Charles  21.0
# 51                   Nosworthy, Mr. Richard Cater  21.0
# 56                              Rugg, Miss. Emily  21.0
# ..                                            ...   ...
# 864                        Gill, Mr. John William  24.0
# 876                 Gustafsson, Mr. Alfred Ossian  20.0
# 880  Shelley, Mrs. William (Imanita Parrish Hall)  25.0
# 882                  Dahlberg, Miss. Gerda Ulrika  22.0
# 884                        Sutehall, Mr. Henry Jr  25.0
#
# [137 rows x 2 columns]

# %%
df.loc[~filt,['Name','Age']]
# Out:
#                                                   Name   Age
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# 5                                     Moran, Mr. James   NaN
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [754 rows x 2 columns]

# %%
filt = df['Name'].str.contains('William',na=False)

# %%
df.loc[filt,'Name']
# Out:
# 4                            Allen, Mr. William Henry
# 12                     Saundercock, Mr. William Henry
# 17                       Williams, Mr. Charles Eugene
# 23                       Sloper, Mr. William Thompson
# 31     Spencer, Mrs. William Augustus (Marie Eugenie)
#                             ...
# 802               Carter, Master. William Thornton II
# 810                            Alexander, Mr. William
# 864                            Gill, Mr. John William
# 880      Shelley, Mrs. William (Imanita Parrish Hall)
# 885              Rice, Mrs. William (Margaret Norton)
# Name: Name, Length: 69, dtype: object

# %%
filt = (df['Age'] < 10.0 ) | (df['Age'] > 90.0)

# %%
df.loc[filt,['Name','Age']]
# Out:
#                                          Name   Age
# 7              Palsson, Master. Gosta Leonard  2.00
# 10            Sandstrom, Miss. Marguerite Rut  4.00
# 16                       Rice, Master. Eugene  2.00
# 24              Palsson, Miss. Torborg Danira  8.00
# 43   Laroche, Miss. Simonne Marie Anne Andree  3.00
# ..                                        ...   ...
# 827                     Mallet, Master. Andre  1.00
# 831           Richards, Master. George Sibley  0.83
# 850   Andersson, Master. Sigvard Harald Elias  4.00
# 852                   Boulos, Miss. Nourelain  9.00
# 869           Johnson, Master. Harold Theodor  4.00
#
# [62 rows x 2 columns]
